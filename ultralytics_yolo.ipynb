# %% [markdown]
# # How to start?
# > Te file path of this directory list is `/content`
# > For example:<br>
# > After I execute `!git clone https://github.com/ultralytics/yolov5.git`, you will see the `yolov5` directory on left side bar, and the file path of `yolov5/` is `/content/yolov5`.
#
#
# 1. upload images(`sample1~4.jpg`, `video1.MOV` in the `content/` (like below)
# 2. start to run the below code block
#
# Current Directory list
# ```
# !pwd
# /content/
#
# |- ..
# |- yolo5/
# |- sample_data/
# |- sample1.jpg
# |- sample2.jpg
# |- sample3.jpg
# |- sample4.jpg
# |- video1.MOV
#
# ```

# %% [markdown]
# # 1. YOLOv5
# Clone the YOLOv5 repository from GitHub and change to the `yolov5` directory to access its files and models

# %%
# clone the YOLOv5 repository from GitHub and change to the 'yolov5' directory to access its files and models
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pwd
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Receiving objects: 100% (16575/16575), 15.10 MiB | 16.93 MiB/s, done.
# Resolving deltas: 100% (11385/11385), done.
# /content/yolov5
# '/content/yolov5'

# %% [markdown]
# ## 1.1 Package Installation
# Install required Python packages from requirements.txt using subprocess to ensure compatibility with the current environment.

# %%
import subprocess
import sys
import os
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-r', 'requirements.txt'])
# Out:
# 0

# %% [markdown]
# ## 1.2 Executing Object Detection on **Image** Using `YOLOv5` with Python `Subprocess`
# This script executes the `detect.py` Python script to perform object detection on the **image** file `test_yolo.jpeg,` using predefined model parameters and ensuring output handling with `UTF-8` encoding.
# <br>
# Execute like this: `python detect.py --weights yolov5s.pt --img 416 --conf 0.4 --source /content/test_yolo.jpeg
# `
#
# Here, I execute four sources:
# 1. sample1.jpg
# 2. smpale2.jpg
# 3. sample3.jpg
# 4. sample4.jpg
#
# source image: `sample1.jpg`
# output location will show in the log:
# ```
# Speed: 0.6ms pre-process, 46.7ms inference, 585.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2
#
# ```
# `runs/detect/exp2` is in the `yolov5/`, so it's completed file path is `yolov5/runs/detect/exp2/`

# %%
# set the environment variable to ensure UTF-8 encoding
my_env = os.environ.copy()
my_env["PYTHONIOENCODING"] = "UTF-8"
my_env["LC_ALL"] = "C.UTF-8"
my_env["LANG"] = "C.UTF-8"

# %%
import subprocess

# define your command and arguments
command = [
    'python', 'detect.py',
    '--weights', 'yolov5s.pt',
    '--img', '416',
    '--conf', '0.4',
    '--source', '/content/sample1.jpg'
]

# run the command with Popen
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, env=my_env)
output, error = process.communicate()

# print output and errors, if any
print(output.decode())
if error:
    print(error.decode())
# Out:
# detect: weights=['yolov5s.pt'], source=/content/sample1.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 211MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/sample1.jpg: 320x416 2 bottles, 1 laptop, 1 cell phone, 1 microwave, 50.0ms
# Speed: 0.6ms pre-process, 50.0ms inference, 639.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %% [markdown]
# ## 1.3 Executing Object Detection on Video Using `YOLOv5` with Python `Subprocess`
# This script uses Python's `subprocess` module to object detection on the <b>video</b> file `test_yolo.mp4` using `YOLOv5`. The process handles output and errors efficiently in a `UTF-8 encoding`.
#
# source image: `video1.MOV`
# output location will show in the log:
# ```
# Speed: 0.5ms pre-process, 13.0ms inference, 4.6ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/expxx
#
# ```
# `runs/detect/predict` is in the `yolov5/`, so its completed file path is `yolov5/runs/detect/predict/.`

# %%
import subprocess
import os
# Define your command and arguments
command = [
    'python', 'detect.py',
    '--weights', 'yolov5s.pt',
    '--img', '416',
    '--conf', '0.4',
    '--source', '/content/video1.MOV'
]

# Set the environment variable to ensure UTF-8 encoding
my_env = os.environ.copy()
my_env["PYTHONIOENCODING"] = "UTF-8"
my_env["LC_ALL"] = "C.UTF-8"
my_env["LANG"] = "C.UTF-8"

# Run the command with Popen
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, env=my_env)
output, error = process.communicate()

# Print output and errors, if any
print(output.decode())
if error:
    print(error.decode())
# Out:
# detect: weights=['yolov5s.pt'], source=/content/video1.MOV, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 139.7ms
# video 1/1 (2/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 24.0ms
# video 1/1 (3/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 12.1ms
# video 1/1 (4/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 19.5ms
# video 1/1 (5/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 12.5ms
# video 1/1 (6/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 12.4ms
# video 1/1 (7/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 12.6ms
# video 1/1 (8/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 11.0ms
# video 1/1 (9/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.9ms
# video 1/1 (10/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.7ms
# video 1/1 (11/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.4ms
# video 1/1 (12/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 11.1ms
# video 1/1 (13/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.7ms
# video 1/1 (14/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.3ms
# video 1/1 (15/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.6ms
# video 1/1 (16/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 10.3ms
# video 1/1 (17/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.6ms
# video 1/1 (18/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (19/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 12.2ms
# video 1/1 (20/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (21/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.9ms
# video 1/1 (22/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (23/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 11.2ms
# video 1/1 (24/207) /content/video1.MOV: 416x256 3 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (25/207) /content/video1.MOV: 416x256 3 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (26/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.1ms
# video 1/1 (27/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 9.8ms
# video 1/1 (28/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 11.0ms
# video 1/1 (29/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 11.1ms
# video 1/1 (30/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 22.7ms
# video 1/1 (31/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 11.0ms
# video 1/1 (32/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.9ms
# video 1/1 (33/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (34/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.6ms
# video 1/1 (35/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 11.0ms
# video 1/1 (36/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.8ms
# video 1/1 (37/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (38/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 11.1ms
# video 1/1 (39/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (40/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (41/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.6ms
# video 1/1 (42/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (43/207) /content/video1.MOV: 416x256 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.3ms
# video 1/1 (44/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.6ms
# video 1/1 (45/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (46/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (47/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.7ms
# video 1/1 (48/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 13.3ms
# video 1/1 (49/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (50/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 10.7ms
# video 1/1 (51/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.4ms
# video 1/1 (52/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.3ms
# video 1/1 (53/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.4ms
# video 1/1 (54/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.3ms
# video 1/1 (55/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.7ms
# video 1/1 (56/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (57/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.9ms
# video 1/1 (58/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (59/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 9.6ms
# video 1/1 (60/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 11.0ms
# video 1/1 (61/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.8ms
# video 1/1 (62/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 cell phone, 10.6ms
# video 1/1 (63/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 11.1ms
# video 1/1 (64/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 10.9ms
# video 1/1 (65/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 11.0ms
# video 1/1 (66/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 11.0ms
# video 1/1 (67/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 14.9ms
# video 1/1 (68/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 10.6ms
# video 1/1 (69/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 10.4ms
# video 1/1 (70/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 10.5ms
# video 1/1 (71/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.5ms
# video 1/1 (72/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 1 cell phone, 10.4ms
# video 1/1 (73/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 1 cell phone, 10.3ms
# video 1/1 (74/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (75/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 cell phone, 10.3ms
# video 1/1 (76/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.6ms
# video 1/1 (77/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (78/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.6ms
# video 1/1 (79/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.4ms
# video 1/1 (80/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 cell phone, 10.8ms
# video 1/1 (81/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (82/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (83/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 11.1ms
# video 1/1 (84/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 11.2ms
# video 1/1 (85/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 cell phone, 11.0ms
# video 1/1 (86/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 14.4ms
# video 1/1 (87/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 cell phone, 10.8ms
# video 1/1 (88/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.7ms
# video 1/1 (89/207) /content/video1.MOV: 416x256 2 tvs, 1 mouse, 1 keyboard, 1 cell phone, 10.8ms
# video 1/1 (90/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 cell phone, 12.9ms
# video 1/1 (91/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 9.6ms
# video 1/1 (92/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.5ms
# video 1/1 (93/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.7ms
# video 1/1 (94/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 remote, 2 keyboards, 10.5ms
# video 1/1 (95/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.7ms
# video 1/1 (96/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.6ms
# video 1/1 (97/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.6ms
# video 1/1 (98/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.6ms
# video 1/1 (99/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.6ms
# video 1/1 (100/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.6ms
# video 1/1 (101/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 2 keyboards, 10.8ms
# video 1/1 (102/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 2 keyboards, 10.9ms
# video 1/1 (103/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 11.2ms
# video 1/1 (104/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.9ms
# video 1/1 (105/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.8ms
# video 1/1 (106/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 16.8ms
# video 1/1 (107/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.4ms
# video 1/1 (108/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.4ms
# video 1/1 (109/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 10.3ms
# video 1/1 (110/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (111/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.6ms
# video 1/1 (112/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 10.4ms
# video 1/1 (113/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 10.6ms
# video 1/1 (114/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.5ms
# video 1/1 (115/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 10.3ms
# video 1/1 (116/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 11.0ms
# video 1/1 (117/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 11.2ms
# video 1/1 (118/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.9ms
# video 1/1 (119/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 20.1ms
# video 1/1 (120/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 16.7ms
# video 1/1 (121/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 9.0ms
# video 1/1 (122/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 12.2ms
# video 1/1 (123/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 17.3ms
# video 1/1 (124/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 9.8ms
# video 1/1 (125/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 9.5ms
# video 1/1 (126/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 1 book, 15.7ms
# video 1/1 (127/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 15.5ms
# video 1/1 (128/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 15.6ms
# video 1/1 (129/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 21.9ms
# video 1/1 (130/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 12.4ms
# video 1/1 (131/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 15.9ms
# video 1/1 (132/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 14.3ms
# video 1/1 (133/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 15.1ms
# video 1/1 (134/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 20.9ms
# video 1/1 (135/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 20.0ms
# video 1/1 (136/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 19.1ms
# video 1/1 (137/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 17.6ms
# video 1/1 (138/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 8.5ms
# video 1/1 (139/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 13.4ms
# video 1/1 (140/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 15.4ms
# video 1/1 (141/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 22.6ms
# video 1/1 (142/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 22.8ms
# video 1/1 (143/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 18.8ms
# video 1/1 (144/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 19.4ms
# video 1/1 (145/207) /content/video1.MOV: 416x256 2 tvs, 2 mouses, 1 keyboard, 1 book, 20.5ms
# video 1/1 (146/207) /content/video1.MOV: 416x256 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 10.2ms
# video 1/1 (147/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 10.6ms
# video 1/1 (148/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 11.1ms
# video 1/1 (149/207) /content/video1.MOV: 416x256 1 tv, 2 laptops, 2 mouses, 1 keyboard, 10.4ms
# video 1/1 (150/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.1ms
# video 1/1 (151/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.4ms
# video 1/1 (152/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.2ms
# video 1/1 (153/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 10.5ms
# video 1/1 (154/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 10.3ms
# video 1/1 (155/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 1 book, 9.8ms
# video 1/1 (156/207) /content/video1.MOV: 416x256 2 mouses, 1 keyboard, 1 book, 11.0ms
# video 1/1 (157/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.2ms
# video 1/1 (158/207) /content/video1.MOV: 416x256 2 mouses, 1 keyboard, 1 book, 10.2ms
# video 1/1 (159/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 11.1ms
# video 1/1 (160/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.6ms
# video 1/1 (161/207) /content/video1.MOV: 416x256 2 mouses, 1 keyboard, 1 book, 10.3ms
# video 1/1 (162/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.1ms
# video 1/1 (163/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.5ms
# video 1/1 (164/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 book, 10.2ms
# video 1/1 (165/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.4ms
# video 1/1 (166/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.8ms
# video 1/1 (167/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 book, 10.8ms
# video 1/1 (168/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.4ms
# video 1/1 (169/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.3ms
# video 1/1 (170/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 1 book, 10.2ms
# video 1/1 (171/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 1 book, 10.2ms
# video 1/1 (172/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 1 book, 10.1ms
# video 1/1 (173/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 1 book, 9.9ms
# video 1/1 (174/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 1 book, 9.9ms
# video 1/1 (175/207) /content/video1.MOV: 416x256 1 tv, 1 laptop, 2 mouses, 1 keyboard, 10.1ms
# video 1/1 (176/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 10.3ms
# video 1/1 (177/207) /content/video1.MOV: 416x256 1 tv, 2 mouses, 1 keyboard, 10.7ms
# video 1/1 (178/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 1 keyboard, 10.1ms
# video 1/1 (179/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.4ms
# video 1/1 (180/207) /content/video1.MOV: 416x256 1 laptop, 1 mouse, 10.4ms
# video 1/1 (181/207) /content/video1.MOV: 416x256 2 mouses, 10.3ms
# video 1/1 (182/207) /content/video1.MOV: 416x256 2 mouses, 10.3ms
# video 1/1 (183/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 10.4ms
# video 1/1 (184/207) /content/video1.MOV: 416x256 1 laptop, 2 mouses, 10.4ms
# video 1/1 (185/207) /content/video1.MOV: 416x256 2 mouses, 10.9ms
# video 1/1 (186/207) /content/video1.MOV: 416x256 2 mouses, 11.3ms
# video 1/1 (187/207) /content/video1.MOV: 416x256 2 mouses, 9.9ms
# video 1/1 (188/207) /content/video1.MOV: 416x256 2 mouses, 10.3ms
# video 1/1 (189/207) /content/video1.MOV: 416x256 2 mouses, 10.8ms
# video 1/1 (190/207) /content/video1.MOV: 416x256 2 mouses, 1 book, 10.4ms
# video 1/1 (191/207) /content/video1.MOV: 416x256 1 mouse, 10.7ms
# video 1/1 (192/207) /content/video1.MOV: 416x256 1 cup, 1 mouse, 11.0ms
# video 1/1 (193/207) /content/video1.MOV: 416x256 1 cup, 1 mouse, 1 book, 10.3ms
# video 1/1 (194/207) /content/video1.MOV: 416x256 1 cup, 1 book, 10.5ms
# video 1/1 (195/207) /content/video1.MOV: 416x256 1 cup, 1 book, 10.6ms
# video 1/1 (196/207) /content/video1.MOV: 416x256 1 mouse, 11.9ms
# video 1/1 (197/207) /content/video1.MOV: 416x256 1 mouse, 1 book, 10.8ms
# video 1/1 (198/207) /content/video1.MOV: 416x256 1 mouse, 1 book, 10.5ms
# video 1/1 (199/207) /content/video1.MOV: 416x256 1 mouse, 10.5ms
# video 1/1 (200/207) /content/video1.MOV: 416x256 1 mouse, 11.7ms
# video 1/1 (201/207) /content/video1.MOV: 416x256 1 mouse, 10.4ms
# video 1/1 (202/207) /content/video1.MOV: 416x256 1 mouse, 10.5ms
# video 1/1 (203/207) /content/video1.MOV: 416x256 2 laptops, 1 mouse, 19.8ms
# video 1/1 (204/207) /content/video1.MOV: 416x256 1 laptop, 1 mouse, 12.0ms
# video 1/1 (205/207) /content/video1.MOV: 416x256 1 mouse, 6.3ms
# video 1/1 (206/207) /content/video1.MOV: 416x256 1 mouse, 6.6ms
# video 1/1 (207/207) /content/video1.MOV: 416x256 1 mouse, 6.2ms
# Speed: 0.5ms pre-process, 12.2ms inference, 6.7ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %% [markdown]
# # 2.YOLOv8 Direct Use
# Implement YOLOv8 for Object Detection and Tracking in Python.

# %% [markdown]
# ## 2.1 Library Installation
# Install PyTorch, Torchvision, and specific versions of the Ultralytics packages necessary for running YOLOv8.

# %%
# !pip install torch torchvision
# !pip install -U ultralytics
# !pip install yolov5
# !pip install ultralytics==8.0.196
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Collecting yolov5
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.10/dist-packages (from yolov5) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from yolov5) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from yolov5) (10.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from yolov5) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.11.4)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.66.2)
# Requirement already satisfied: ultralytics>=8.0.100 in /usr/local/lib/python3.10/dist-packages (from yolov5) (8.2.6)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.15.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.13.1)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (67.7.2)
# Collecting fire (from yolov5)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.34.96-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 15.2 MB/s eta 0:00:00
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.15-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.20.3)
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.1.28-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 10.1 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.96 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.34.96-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 44.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython>=3.1.30->yolov5) (4.0.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->yolov5) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->yolov5) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2024.2.2)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->yolov5)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 23.7 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow>=0.2.29->yolov5)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.4 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib>=3.3->yolov5)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->yolov5)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# Collecting opencv-python-headless==4.8.0.74 (from roboflow>=0.2.29->yolov5)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.4 MB/s eta 0:00:00
# Collecting python-dotenv (from roboflow>=0.2.29->yolov5)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow>=0.2.29->yolov5) (1.16.0)
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# Collecting python-magic (from roboflow>=0.2.29->yolov5)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (2.0.4)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (8.1.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.63.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->yolov5) (12.4.127)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->yolov5) (2.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->yolov5) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->yolov5) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->yolov5) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=fd5042c5460c2e2d0eb33fd78b46e62012631d2b953a5a5222d195f319377504
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: terminaltables, python-magic, python-dotenv, pybboxes, opencv-python-headless, opencv-python, jmespath, idna, fire, cycler, chardet, certifi, botocore, sahi, s3transfer, requests-toolbelt, roboflow, boto3, yolov5
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# Successfully installed boto3-1.34.96 botocore-1.34.96 certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 fire-0.6.0 idna-2.10 jmespath-1.0.1 opencv-python-4.7.0.72 opencv-python-headless-4.8.0.74 pybboxes-0.1.6 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.28 s3transfer-0.10.1 sahi-0.11.15 terminaltables-3.1.10 yolov5-7.0.13
# Collecting ultralytics==8.0.196
#   Downloading ultralytics-8.0.196-py3-none-any.whl (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (1.25.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (4.7.0.72)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (4.66.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (0.13.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.196) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.0.196) (12.4.127)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics==8.0.196) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
#     conflicts = self._determine_conflicts(to_install)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 572, in _determine_conflicts
#     return check_install_conflicts(to_install)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/pkg_resources.py", line 216, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2821, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3110, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3132, in _compute_dependencies
#     dm[s_extra] = [r for r in reqs_for_extra(extra) if r not in common]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3132, in <listcomp>
#     dm[s_extra] = [r for r in reqs_for_extra(extra) if r not in common]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3124, in reqs_for_extra
#     if not req.marker or req.marker.evaluate({'extra': extra}):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/markers.py", line 304, in evaluate
#     return _evaluate_markers(self._markers, current_environment)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/markers.py", line 226, in _evaluate_markers
#     assert isinstance(marker, (list, tuple, str))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 223, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 206, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.10/logging/__init__.py", line 1524, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1624, in _log
#     self.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 968, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/console.py", line 1701, in print
#     extend(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/segment.py", line 198, in <genexpr>
#     result_segments = (
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/console.py", line 1330, in render
#     for render_output in iter_render:
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/text.py", line 660, in __rich_console__
#     no_wrap=pick_bool(self.no_wrap, options.no_wrap, False),
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/rich/_pick.py", line 4, in pick_bool
#     def pick_bool(*values: Optional[bool]) -> bool:
# KeyboardInterrupt
# ^C

# %% [markdown]
# ## 2.2 Import Libraries and Predict & **DIRECT USE**
# Import necessary Python libraries and modules, sets up the `IPython` display, and performs an object detection prediction on an image using YOLOv8.
#
# source image: `sample1.jpg`
# output location will show in the log:
# ```
# Results saved to runs/detect/predict
# ```
# `runs/detect/predict` is in the `yolov5/`, so it's completed file path is `yolov5/runs/detect/predict/`

# %%
from IPython import display
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
import torch
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 67.8MB/s]
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample1.jpg: 480x640 1 bottle, 1 cup, 1 laptop, 1 cell phone, 73.1ms
# Speed: 3.8ms preprocess, 73.1ms inference, 2015.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## 2.3 Image Predict & **DIRECT USE**
# Execute different samples

# %%
# !yolo predict model=yolov8n.pt source='/content/sample1.jpg'
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/sample1.jpg: 480x640 1 bottle, 1 cup, 1 laptop, 1 cell phone, 71.5ms
# Speed: 3.7ms preprocess, 71.5ms inference, 2333.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
